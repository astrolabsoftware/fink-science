# %%
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
import matplotlib.pyplot as plt

from pyspark.sql.types import *
from pyspark.sql.functions import pandas_udf
import pyspark.sql.functions as F
from astropy.time import Time

from fink_filters.classification import extract_fink_classification

from fink_science.fast_transient_rate.processor import (
    fast_transient_rate,
    fast_transient_module,
)
from fink_science.fast_transient_rate import rate_module_output_schema
# Out:
# /opt/spark-3/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)
# /opt/spark-3/python/pyspark/sql/pandas/functions.py:392: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   "in the future releases. See SPARK-28264 for more details.", UserWarning)

# %%
def fink_classification(spark_df):
    return spark_df.withColumn(
        "fink_class",
        extract_fink_classification(
            spark_df.cdsxmatch,
            spark_df.roid,
            spark_df.mulens,
            spark_df.snn_snia_vs_nonia,
            spark_df.snn_sn_vs_all,
            spark_df.rf_snia_vs_nonia,
            spark_df.candidate.ndethist,
            spark_df.candidate.drb,
            spark_df.candidate.classtar,
            spark_df.candidate.jd,
            spark_df.candidate.jdstarthist,
            spark_df.rf_kn_vs_nonkn,
            spark_df.tracklet,
        ),
    )

# %%
def compute_and_save_ftmodule(path_data):
    df = (
        spark.read
        .option("basePath", "/user/julien.peloton/archive/science/")
        .format("parquet")
        .load(path_data)
    )

    df = fink_classification(df)
    df = fast_transient_module(df, 100)
    requested_cols = [
        "objectId",
        "candid",
        "fink_class",
        "cast(candidate.ra as double)",
        "cast(candidate.dec as double)",
        "cast(candidate.magpsf as double)",
        "cast(candidate.sigmapsf as double)",
        "cast(candidate.diffmaglim as double)",
        "cast(candidate.fid as integer)",
        "cast(candidate.jd as double)",
        "cast(candidate.jdstarthist as double)",
        "cast(candidate.distnr as double)",
        "cast(candidate.distpsnr1 as double)",
        "cast(candidate.drb as double)",
        "cast(candidate.rb as double)",
        "cast(nalerthist as integer)",
        "year",
        "month",
    ] + list(rate_module_output_schema.keys())

    df.selectExpr(requested_cols).write.mode("append").partitionBy(
        "year", "month"
    ).parquet("fast_transient_module_data/")

# %% [markdown]
# ### Run the fast transient module over all the Fink data and save it on hdfs

# %%
path_data = [
    "/user/julien.peloton/archive/science/year=2019",
    "/user/julien.peloton/archive/science/year=2020",
    "/user/julien.peloton/archive/science/year=2021",
]
compute_and_save_ftmodule(path_data)

# %%
path_data = [
    "/user/julien.peloton/archive/science/year=2022",
    "/user/julien.peloton/archive/science/year=2023",
]
compute_and_save_ftmodule(path_data)

# %% [markdown]
# Output Size : 13.2 GB

# %% [markdown]
# ### Analysis

# %%
df = (
    spark.read
    .option("basePath", "/user/roman.le-montagner/")
    .format("parquet")
    .load("fast_transient_module_data")
    .cache()
)

# %%
df.printSchema()
# Out:
# root
#  |-- objectId: string (nullable = true)
#  |-- candid: long (nullable = true)
#  |-- fink_class: string (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- magpsf: double (nullable = true)
#  |-- sigmapsf: double (nullable = true)
#  |-- diffmaglim: double (nullable = true)
#  |-- fid: integer (nullable = true)
#  |-- jd: double (nullable = true)
#  |-- jdstarthist: double (nullable = true)
#  |-- distnr: double (nullable = true)
#  |-- distpsnr1: double (nullable = true)
#  |-- drb: double (nullable = true)
#  |-- nalerthist: integer (nullable = true)
#  |-- jd_first_real_det: double (nullable = true)
#  |-- jdstarthist_dt: double (nullable = true)
#  |-- mag_rate: double (nullable = true)
#  |-- sigma_rate: double (nullable = true)
#  |-- lower_rate: double (nullable = true)
#  |-- upper_rate: double (nullable = true)
#  |-- delta_time: double (nullable = true)
#  |-- from_upper: boolean (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)

# %%
df.groupBy("fink_class").count().orderBy("count", ascending=False).show(300)
# Out:
# +--------------------+--------+
# |          fink_class|   count|
# +--------------------+--------+
# |             Unknown|59037700|
# |    Solar System MPC|15759160|
# |                  V*| 7404401|
# |               RRLyr| 6223806|
# |       Candidate_EB*| 5429979|
# |                 EB*| 3800466|
# |                 QSO| 2513208|
# |                Star| 2025969|
# |       Candidate_LP*| 1986151|
# |                Mira| 1641072|
# |       EB*_Candidate| 1509089|
# |                LPV*| 1231509|
# |     Candidate_RRLyr|  751057|
# |              PulsV*|  552584|
# |       LP*_Candidate|  537499|
# |           Seyfert_1|  535969|
# |        SN candidate|  522094|
# |Solar System cand...|  393476|
# |                  C*|  314014|
# |                 YSO|  212318|
# |     RRLyr_Candidate|  211709|
# |       Candidate_YSO|  199616|
# |               BLLac|  172383|
# |                Blue|  161128|
# |           CataclyV*|  151649|
# |            deltaCep|  113917|
# |            Tracklet|  112927|
# |                 Em*|  110887|
# |               TTau*|  105257|
# |       AGN_Candidate|   96301|
# |               RSCVn|   79398|
# |            Orion_V*|   78159|
# |               RotV*|   72019|
# |       YSO_Candidate|   69269|
# |               Radio|   68402|
# |        PulsV*delSct|   57023|
# |                 AGN|   55168|
# |                  SN|   53530|
# |        Candidate_C*|   50769|
# |                AGB*|   47413|
# |          PulsV*WVir|   44120|
# |                  S*|   41207|
# |                Pec*|   34212|
# |                 HB*|   32529|
# |                RGB*|   28955|
# |       Candidate_Mi*|   25412|
# |       Candidate_CV*|   23545|
# |              RedSG*|   20756|
# |                   X|   20489|
# |             Cepheid|   19297|
# |                  IR|   17175|
# |           Seyfert_2|   16898|
# |               OH/IR|   15871|
# |                Nova|   14156|
# |              Blazar|   13565|
# |                 Be*|   12959|
# |      Candidate_AGB*|   12837|
# |                 NIR|   12270|
# |        C*_Candidate|   11638|
# |Early SN Ia candi...|   11268|
# |                  **|   10761|
# |                 SB*|   10751|
# |           Ambiguous|    9567|
# |           Eruptive*|    8994|
# |                 PM*|    8911|
# |           low-mass*|    8890|
# |            EllipVar|    8676|
# |                 MIR|    8127|
# |               BYDra|    7986|
# |       QSO_Candidate|    7293|
# |          Symbiotic*|    7173|
# |         PulsV*RVTau|    6826|
# |       Mi*_Candidate|    6786|
# |       CV*_Candidate|    6019|
# |               GinCl|    5821|
# |       Candidate_SN*|    5749|
# |            GinGroup|    5739|
# |                  PN|    5686|
# |         HotSubdwarf|    5646|
# |                BClG|    5420|
# |Microlensing cand...|    4858|
# |                 WD*|    4780|
# |      AGB*_Candidate|    4650|
# |               LINER|    4626|
# |          Erupt*RCrB|    4257|
# |        Irregular_V*|    4256|
# |             Seyfert|    4225|
# |             BlueSG*|    3823|
# |                 Ae*|    3795|
# |       Candidate_HB*|    3500|
# |       Candidate_WD*|    3496|
# |       BlueStraggler|    3407|
# |      Candidate_RSG*|    3305|
# |     Candidate_TTau*|    3214|
# |            pulsV*SX|    3139|
# |                  UV|    3043|
# |              RadioG|    2949|
# |                 EmG|    2659|
# |       WD*_Candidate|    2626|
# |                HMXB|    2494|
# |                 V*?|    2386|
# |           Radio(cm)|    2203|
# |                 PN?|    2165|
# |    Blazar_Candidate|    2160|
# |           post-AGB*|    2080|
# |            gammaDor|    2029|
# |                  XB|    1974|
# |                 HII|    1808|
# |      GravLensSystem|    1643|
# |     BLLac_Candidate|    1535|
# |       SN*_Candidate|    1477|
# |               EmObj|    1455|
# |                 ClG|    1232|
# |                 FIR|    1185|
# |             Planet?|    1179|
# |      RSG*_Candidate|    1146|
# |                LMXB|    1112|
# |             GinPair|    1075|
# |       HB*_Candidate|    1012|
# |        RotV*alf2CVn|     993|
# |                 WR*|     974|
# |       PN?_Candidate|     900|
# |       Candidate_Hsd|     897|
# |     TTau*_Candidate|     894|
# |                GlCl|     841|
# |           YellowSG*|     640|
# |       Candidate_Be*|     602|
# |       Candidate_Ae*|     581|
# |       V*?_Candidate|     566|
# |              Pulsar|     527|
# |       Be*_Candidate|     497|
# |              Planet|     488|
# |                 SG*|     471|
# |             PartofG|     464|
# |   Unknown_Candidate|     454|
# |               gamma|     432|
# |          PulsV*bCep|     390|
# |Candidate_LensSystem|     384|
# |     multiple_object|     377|
# |  Kilonova candidate|     373|
# |        Candidate_S*|     336|
# |   Candidate_Cepheid|     320|
# |   Planet?_Candidate|     313|
# |           denseCore|     311|
# |          Inexistent|     307|
# |               LSB_G|     299|
# |             LensedQ|     294|
# |       Hsd_Candidate|     285|
# |              MolCld|     270|
# |                 Cl*|     269|
# |               PairG|     267|
# |              Assoc*|     265|
# |        Compact_Gr_G|     248|
# |       Ae*_Candidate|     242|
# | Candidate_post-AGB*|     239|
# |                  HH|     230|
# |         LensedImage|     214|
# |              GroupG|     205|
# |               DkNeb|     196|
# |               HII_G|     187|
# |LensSystem_Candidate|     186|
# |          gammaBurst|     184|
# |   Candidate_brownD*|     177|
# |               GlCl?|     175|
# |                 HV*|     169|
# |   brownD*_Candidate|     168|
# |            GravLens|     162|
# |                  IG|     149|
# |       Candidate_WR*|     135|
# |           LensingEv|     134|
# |       SB*_Candidate|     131|
# |  Possible_lensImage|     128|
# |      Candidate_BSG*|     115|
# | post-AGB*_Candidate|     114|
# |   Cepheid_Candidate|     112|
# |             brownD*|     111|
# |                 SNR|     107|
# |      Candidate_RGB*|      98|
# |              Bubble|      98|
# |               RfNeb|      96|
# |      Candidate_Nova|      86|
# |                OpCl|      84|
# |       Radio(sub-mm)|      83|
# |               Maser|      81|
# |      RCrB_Candidate|      77|
# |        S*_Candidate|      68|
# |           Radio(mm)|      63|
# |       WR*_Candidate|      56|
# |              Region|      54|
# |             HIshell|      50|
# |       BSS_Candidate|      44|
# |               HVCld|      43|
# |     Candidate_Symb*|      41|
# |                 ISM|      39|
# |          StarburstG|      39|
# |      BSG*_Candidate|      33|
# |         PartofCloud|      32|
# |      RGB*_Candidate|      32|
# |                  HI|      30|
# |      Nova_Candidate|      29|
# |      Candidate_LMXB|      28|
# |          Possible_G|      23|
# |             Globule|      23|
# | lensImage_Candidate|      22|
# |     Symb*_Candidate|      20|
# |         G_Candidate|      20|
# |               Cloud|      19|
# |      Candidate_Lens|      18|
# |      LMXB_Candidate|      17|
# |                Cl*?|      16|
# |                SNR?|      15|
# |       Candidate_XB*|      15|
# |       Candidate_SB*|      14|
# |       ClG_Candidate|      12|
# |                Void|      11|
# |             LensedG|      11|
# |           BlueCompG|      11|
# |       Candidate_SG*|      11|
# |            SFregion|       9|
# |              GalNeb|       8|
# |      SNR?_Candidate|       8|
# |     GlCl?_Candidate|       8|
# |      Lens_Candidate|       7|
# | Candidate_low-mass*|       6|
# |       El*_Candidate|       5|
# |      Candidate_YSG*|       3|
# |            SuperClG|       3|
# |            outflow?|       3|
# |        Possible_ClG|       2|
# |       SG*_Candidate|       2|
# |        Possible_GrG|       2|
# |                 ULX|       1|
# |             Outflow|       1|
# |       GrG_Candidate|       1|
# |       XB*_Candidate|       1|
# |      HMXB_Candidate|       1|
# |      Candidate_HMXB|       1|
# +--------------------+--------+

# %%
selected_cols = [
    "objectId",
    "fink_class",
    "magpsf",
    "sigmapsf",
    "fid",
    "diffmaglim",
    "jd",
    "mag_rate",
    "sigma_rate",
    "lower_rate",
    "upper_rate",
    "from_upper",
]

# %%
some_variable_star = ["RRLyr", "Mira", "PulsV*", "EB*", "YSO", "deltaCep"]

local_vs = (
    df.filter(df.fink_class.isin(some_variable_star)).select(selected_cols).toPandas()
)

# %%
local_vs
# Out:
#               objectId fink_class     magpsf  sigmapsf  fid  diffmaglim  \
# 0         ZTF18abtmoxu        EB*  17.662386  0.081151    1   19.869539
# 1         ZTF18abspnmv      RRLyr  18.562780  0.135149    1   19.707409
# 2         ZTF17aabukwo        EB*  17.861448  0.048640    1   19.953129
# 3         ZTF17aabcjkw        EB*  18.753481  0.137195    1   20.145414
# 4         ZTF18adnpdim        EB*  18.583513  0.080696    1   20.087093
# ...                ...        ...        ...       ...  ...         ...
# 12544158  ZTF18abccnkb        EB*  17.599257  0.079423    2   18.545355
# 12544159  ZTF18abebuuf        EB*  18.324001  0.164355    2   18.541004
# 12544160  ZTF18abcoyxj        EB*  16.138521  0.071125    2   18.762545
# 12544161  ZTF19aaafpfi      RRLyr  15.619508  0.016759    2   18.951569
# 12544162  ZTF19aaaqjnp      RRLyr  16.821634  0.066623    2   18.610394
#
#                     jd  mag_rate  sigma_rate  lower_rate  upper_rate  \
# 0         2.459969e+06 -0.004918    0.008619   -0.019820    0.010888
# 1         2.459969e+06 -0.033575    0.015408   -0.060599   -0.011175
# 2         2.459969e+06 -0.021817    0.006530   -0.033746   -0.012305
# 3         2.459969e+06 -0.004836    0.069581   -0.135087    0.072017
# 4         2.459969e+06  0.013608    0.009165   -0.001522    0.027824
# ...                ...       ...         ...         ...         ...
# 12544158  2.460022e+06 -2.806314    1.070565   -4.820402   -1.835895
# 12544159  2.460022e+06 -2.061511    1.003274   -4.244012   -1.022567
# 12544160  2.459306e+06 -0.702136    0.214145   -1.093723   -0.489719
# 12544161  2.459224e+06 -0.599592    0.223418   -1.120057   -0.410629
# 12544162  2.459224e+06 -0.904047    0.350734   -1.446217   -0.616746
#
#           from_upper
# 0              False
# 1              False
# 2              False
# 3               True
# 4              False
# ...              ...
# 12544158        True
# 12544159        True
# 12544160        True
# 12544161        True
# 12544162        True
#
# [12544163 rows x 12 columns]

# %% [markdown]
# ### Population Study

# %%
def plot_hist_class(df, min_log, max_log, nbins):
    fig = plt.figure(figsize=(15, 8))

    bins = np.logspace(min_log, max_log, nbins)

    round_float = 6

    unique_class = df["fink_class"].unique()
    for f_class, color in zip(
        unique_class, plt.cm.viridis(np.linspace(0, 1, len(unique_class)))
    ):
        data = (
            df[df["fink_class"] == f_class][["objectId", "mag_rate"]]
            .groupby("objectId")
            .mean()["mag_rate"]
        )

        print(
            "class: ",
            f_class,
            ", min=",
            round(data.min(), round_float),
            ", max=",
            round(data.max(), round_float),
            ", mean=",
            round(np.mean(data), round_float),
        )

        p = plt.hist(data, bins=bins, label=f_class, histtype="step", color=color)

        plt.axvline(np.median(data), linewidth=4, color=color)

    plt.yscale("log")
    plt.xscale("log")
    plt.xlabel("magnitude_rate (mag/day)")
    plt.legend()
    plt.show()

# %%
plot_hist_class(local_vs, -3, 3, 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-7ff28af027e8> in <module>
# ----> 1 plot_hist_class(local_vs, -3, 3, 100)
#
# NameError: name 'local_vs' is not defined

# %%
some_class = ["Early SN Ia candidate", "SN", "QSO", "V*"]

local_class = df.filter(df.fink_class.isin(some_class)).select(selected_cols).toPandas()

# %%
clean_rate = local_class[
    (local_class["lower_rate"] > 0) | (local_class["upper_rate"] < 0)
]
fading_rate = clean_rate[clean_rate["mag_rate"] > 0]
rising_rate = clean_rate[clean_rate["mag_rate"] < 0]

# %%
plot_hist_class(fading_rate, -3, 3, 100)
# Out:
# class:  V* , min= 0.001619 , max= 1306.994709 , mean= 0.812094
# class:  QSO , min= 0.004394 , max= 183.399635 , mean= 0.232156
# class:  SN , min= 0.003952 , max= 100.614603 , mean= 0.510605
# class:  Early SN Ia candidate , min= 0.007944 , max= 0.11846 , mean= 0.029917

# %% [markdown]
# ### Some lightcurves with rate

# %%
nalert = clean_rate.groupby("objectId").count().reset_index()
sample_object = nalert[nalert["fink_class"] > 10]["objectId"].sample(10)

# %%
def plot_magnitude_and_rate(df):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(25, 20), sharex=True)

    fig.suptitle(
        df["objectId"].values[0] + " " + df["fink_class"].values[0], y=0.99, fontsize=25
    )

    for _filt, label_filt in [(1, "g band"), (2, "r band")]:
        tmp_filt = df[df["fid"] == _filt]
        time = Time(tmp_filt["jd"], format="jd")

        ax1.errorbar(
            tmp_filt["jd"],
            tmp_filt["magpsf"],
            tmp_filt["sigmapsf"],
            label=label_filt,
            fmt="o",
            markersize=15,
            linestyle="",
        )

        ax2.errorbar(
            tmp_filt["jd"],
            tmp_filt["mag_rate"],
            [
                tmp_filt["mag_rate"] - tmp_filt["lower_rate"],
                tmp_filt["upper_rate"] - tmp_filt["mag_rate"],
            ],
            label=label_filt,
            fmt="o",
            markersize=15,
            linestyle="",
        )

    # plt.setp(ax2.get_xticklabels(), rotation=45, ha='right')

    # time = Time(df["jd"], format="jd")
    # ax2.set_xticklabels(time.iso, rotation=45, ha='right')

    ax1.set_ylabel("magnitude", fontsize=25)
    ax1.invert_yaxis()
    ax1.tick_params(axis="x", which="major", labelsize=30)
    ax1.tick_params(axis="y", which="major", labelsize=25)

    ax2.set_ylabel("magnitude rate (mag/day)", fontsize=25)
    ax2.invert_yaxis()
    ax2.tick_params(axis="x", which="major", labelsize=30)
    ax2.tick_params(axis="y", which="major", labelsize=25)

    plt.legend(prop={"size": 30})
    plt.tight_layout()
    plt.show()

# %%
clean_rate[clean_rate["objectId"] == "ZTF19adawrly"]
# Out:
#               objectId fink_class     magpsf  sigmapsf  fid  diffmaglim  \
# 7332      ZTF19adawrly        QSO  19.024944  0.141705    2   20.230944
# 147954    ZTF19adawrly        QSO  19.648247  0.170190    1   20.231630
# 196192    ZTF19adawrly        QSO  18.705046  0.116210    2   19.902294
# 220705    ZTF19adawrly        QSO  18.887638  0.100156    2   20.239702
# 260906    ZTF19adawrly        QSO  19.168182  0.111890    1   20.434223
# 547155    ZTF19adawrly        QSO  19.235226  0.111607    2   20.598000
# 592614    ZTF19adawrly        QSO  18.688000  0.167210    2   19.349428
# 613092    ZTF19adawrly        QSO  18.913082  0.145619    2   19.796799
# 902667    ZTF19adawrly        QSO  19.221861  0.172147    2   19.651285
# 996025    ZTF19adawrly        QSO  19.501808  0.116967    1   20.441219
# 1198854   ZTF19adawrly        QSO  19.227034  0.169215    2   20.107229
# 1668874   ZTF19adawrly        QSO  19.296232  0.138392    1   20.413765
# 1862785   ZTF19adawrly        QSO  19.503036  0.150162    1   20.601162
# 2734648   ZTF19adawrly        QSO  18.980110  0.126413    2   19.956364
# 3068518   ZTF19adawrly        QSO  19.292131  0.181775    1   19.356236
# 3094736   ZTF19adawrly        QSO  20.143562  0.190752    1   20.807447
# 4396950   ZTF19adawrly        QSO  19.506618  0.166984    1   20.097578
# 5759865   ZTF19adawrly        QSO  19.558475  0.125913    1   20.710213
# 5857050   ZTF19adawrly        QSO  19.353991  0.136072    1   20.177498
# 6443207   ZTF19adawrly        QSO  19.507950  0.142688    1   20.853834
# 7041164   ZTF19adawrly        QSO  19.803577  0.153844    2   20.679840
# 7216369   ZTF19adawrly        QSO  19.582815  0.126530    1   20.693718
# 7550462   ZTF19adawrly        QSO  19.651775  0.148570    1   20.473705
# 7591635   ZTF19adawrly        QSO  19.543299  0.182525    1   19.720486
# 8307479   ZTF19adawrly        QSO  19.847557  0.215102    1   20.336882
# 8498928   ZTF19adawrly        QSO  19.830832  0.187489    1   20.421608
# 8581596   ZTF19adawrly        QSO  19.794636  0.172948    2   20.609558
# 8689828   ZTF19adawrly        QSO  19.943138  0.193271    2   20.321360
# 9179896   ZTF19adawrly        QSO  19.399450  0.168783    1   20.193262
# 9435772   ZTF19adawrly        QSO  19.667570  0.193246    1   20.566488
# 9442652   ZTF19adawrly        QSO  18.905733  0.077297    1   20.715094
# 9841214   ZTF19adawrly        QSO  19.796007  0.161419    1   20.184204
# 10134803  ZTF19adawrly        QSO  19.612181  0.182705    2   20.194555
#
#                     jd  mag_rate  sigma_rate  lower_rate  upper_rate  \
# 7332      2.459969e+06 -0.171037    0.113616   -0.372815   -0.053140
# 147954    2.459678e+06 -0.300845    0.171480   -0.687062   -0.148229
# 196192    2.459966e+06 -0.094888    0.029483   -0.154135   -0.063085
# 220705    2.459973e+06 -0.115983    0.069871   -0.258103   -0.050994
# 260906    2.459973e+06  0.019371    0.011317    0.000065    0.037779
# 547155    2.460045e+06  0.017168    0.007295    0.004459    0.029248
# 592614    2.459903e+06 -0.102447    0.071347   -0.216330   -0.032091
# 613092    2.459971e+06 -0.130968    0.084003   -0.267366   -0.051252
# 902667    2.459985e+06 -0.053438    0.038213   -0.122572   -0.015504
# 996025    2.459691e+06 -0.117536    0.057380   -0.220383   -0.061608
# 1198854   2.459994e+06  0.018459    0.007783    0.005926    0.033163
# 1668874   2.459997e+06  0.010393    0.005657    0.001374    0.019191
# 1862785   2.459700e+06 -0.077851    0.045168   -0.152061   -0.041810
# 2734648   2.459988e+06 -0.057528    0.035397   -0.121836   -0.023596
# 3068518   2.458916e+06 -0.048798    0.030946   -0.098958   -0.009931
# 3094736   2.459233e+06 -0.045363    0.037769   -0.122612   -0.005723
# 4396950   2.459732e+06 -0.075011    0.043466   -0.149832   -0.034506
# 5759865   2.459256e+06 -0.025432    0.010372   -0.045369   -0.012782
# 5857050   2.458913e+06 -0.017122    0.011450   -0.039869   -0.002107
# 6443207   2.458904e+06 -0.027508    0.013533   -0.057074   -0.010041
# 7041164   2.458904e+06 -0.070626    0.033847   -0.131198   -0.031724
# 7216369   2.458900e+06 -0.025753    0.013075   -0.049414   -0.010359
# 7550462   2.458901e+06 -0.023666    0.013351   -0.044298   -0.005628
# 7591635   2.459354e+06 -0.053751    0.031678   -0.114586   -0.018944
# 8307479   2.459351e+06 -0.066208    0.031971   -0.125986   -0.032495
# 8498928   2.459307e+06 -0.053157    0.034741   -0.111600   -0.018739
# 8581596   2.459195e+06 -0.047324    0.035536   -0.098528   -0.011323
# 8689828   2.458867e+06 -0.039377    0.039535   -0.124736   -0.000063
# 9179896   2.458910e+06 -0.083941    0.039230   -0.168591   -0.045398
# 9435772   2.459366e+06 -0.059780    0.034794   -0.120866   -0.023640
# 9442652   2.458996e+06 -0.013069    0.004089   -0.020553   -0.006185
# 9841214   2.459267e+06 -0.075992    0.064436   -0.227572   -0.004736
# 10134803  2.459704e+06 -0.071232    0.042506   -0.150909   -0.028016
#
#           from_upper
# 7332            True
# 147954          True
# 196192          True
# 220705          True
# 260906         False
# 547155         False
# 592614          True
# 613092          True
# 902667          True
# 996025          True
# 1198854        False
# 1668874        False
# 1862785         True
# 2734648         True
# 3068518         True
# 3094736         True
# 4396950         True
# 5759865        False
# 5857050        False
# 6443207        False
# 7041164         True
# 7216369        False
# 7550462        False
# 7591635         True
# 8307479         True
# 8498928         True
# 8581596         True
# 8689828         True
# 9179896         True
# 9435772         True
# 9442652        False
# 9841214         True
# 10134803        True

# %%
for objId in sample_object:
    obj_example = clean_rate[clean_rate["objectId"] == objId].sort_values("jd")
    plot_magnitude_and_rate(obj_example)

# %% [markdown]
# ### GVOM Application

# %%
print(
    """
Number of alerts in fink: {:,},
Number of unique objects in fink: {:,}
""".format(df.count(), df.select("objectId").distinct().count())
)
# Out:
# Number of alerts in fink: 117,881,663,
# Number of unique objects in fink: 30,378,451

# %% [markdown]
# ### cut drb + galactic latitude + fink class

# %%
@pandas_udf(DoubleType())
def lat_gal(ra, dec):
    return pd.Series(SkyCoord(ra, dec, unit="deg").galactic.b)


@pandas_udf(DoubleType())
def lat_ecliptic(ra, dec):
    return pd.Series(
        SkyCoord(ra, dec, unit="deg").transform_to("geocentricmeanecliptic").lat
    )

# %%
df = df.withColumn("b_gal", lat_gal(df.ra, df.dec))
df = df.withColumn("l_ecl", lat_ecliptic(df.ra, df.dec))

# %%
df_cut_gvom = df.filter(
    (df.drb > 0.9)  # very confident alerts
    & (
        (df.b_gal < -10)  # extra galactic cut
        | (df.b_gal > 10)
    )
    & (df.magpsf < 16)  # bright objects
    & (F.abs(df.mag_rate) > 0.3)  # fast transient
    & (df.fink_class.isin(["Unknown", "Ambiguous", "SN candidate"]))  # class cut
    & (df.jd - df.jdstarthist < 3)  # new transient
    & (
        (df.l_ecl < -10)  # remove potential unknown asteroids
        | (df.l_ecl > 10)
    )
)

# %%
df_gvom_local = df_cut_gvom.toPandas()

# %%
df_gvom_local["night"] = df_gvom_local["jd"].astype(int)

# %%
print(
    """
GVOM filter
Number of alerts in fink: {:,},
Number of unique objects in fink: {:,}
Number of alerts per night: {:.1f} alerts / night
""".format(
        len(df_gvom_local),
        len(df_gvom_local["objectId"].unique()),
        df_gvom_local.groupby("night").count().mean()["objectId"],
    )
)
# Out:
# GVOM filter
# Number of alerts in fink: 13,553,
# Number of unique objects in fink: 13,082
# Number of alerts per night: 38.6 alerts / night

# %%
df_gvom_local.sort_values("jd")
# Out:
#           objectId               candid    fink_class          ra        dec  \
# 6036  ZTF19acmvxdn  1035503222315010055       Unknown  141.032337 -11.266658
# 1306  ZTF19acmxbtp  1035516871415015007       Unknown  177.408929  15.780112
# 1307  ZTF19acmwrck  1035516875915015054       Unknown  179.402477  21.540343
# 5829  ZTF19acmxefo  1035516872615015060       Unknown  179.027496  17.570659
# 1327  ZTF19acmxbtv  1035516871415010097       Unknown  177.088974  15.690470
# ...            ...                  ...           ...         ...        ...
# 1988  ZTF23aafwsuu  2299433873115015007  SN candidate  283.863483  81.824213
# 1459  ZTF23aagpixm  2300398365415015003       Unknown  263.584564   0.080725
# 1471  ZTF23aagsaxq  2301267081515015008       Unknown  203.984577   1.297644
# 1344  ZTF23aahbjbo  2302439141015015003       Unknown  258.057180 -12.883189
# 1358  ZTF23aahouyq  2304460210915015013       Unknown  257.961589 -12.657192
#
#          magpsf  sigmapsf  diffmaglim  fid            jd  ...  lower_rate  \
# 6036  15.613436  0.072977   20.134113    1  2.458790e+06  ...   -0.796609
# 1306  14.451644  0.041271   17.797720    1  2.458790e+06  ...   -2.727676
# 1307  14.930362  0.051397   18.981668    1  2.458790e+06  ...   -2.347607
# 5829  15.889865  0.054963   19.434742    1  2.458790e+06  ...   -1.722094
# 1327  15.922644  0.067575   17.797720    1  2.458790e+06  ...   -2.374852
# ...         ...       ...         ...  ...           ...  ...         ...
# 1988  13.919687  0.017989   20.027298    2  2.460054e+06  ...   -0.371745
# 1459  13.919264  0.026141   20.157679    2  2.460055e+06  ...   -0.423683
# 1471  14.440236  0.031135   20.255787    2  2.460056e+06  ...   -0.373958
# 1344  14.637235  0.030329   20.172201    1  2.460057e+06  ...   -0.530563
# 1358  14.561729  0.023615   20.300949    1  2.460059e+06  ...   -0.439446
#
#       upper_rate  delta_time  from_upper  year  month          b      b_gal  \
# 6036   -0.427328    9.984167        True  2019     11  26.766559  26.766559
# 1306   -1.366690    2.990903        True  2019     11  71.713299  71.713299
# 1307   -1.182383    2.990903        True  2019     11  76.536822  76.536822
# 5829   -0.769529    2.990903        True  2019     11  74.052637  74.052637
# 1327   -0.869667    2.990903        True  2019     11  71.421508  71.421508
# ...          ...         ...         ...   ...    ...        ...        ...
# 1988   -0.262809   23.975972        True  2023      4  26.687986  26.687986
# 1459   -0.283884   21.958345        True  2023      4  17.123254  17.123254
# 1471   -0.261169   22.898611        True  2023      4  62.051104  62.051104
# 1344   -0.309492   14.042187        True  2023      4  15.205007  15.205007
# 1358   -0.277387   16.063264        True  2023      4  15.406633  15.406633
#
#           l_ecl    night
# 6036 -25.122744  2458790
# 1306  13.425430  2458790
# 1307  19.449205  2458790
# 5829  15.694611  2458790
# 1327  13.217879  2458790
# ...         ...      ...
# 1988  74.383575  2460053
# 1459  23.363764  2460054
# 1471  10.510226  2460055
# 1344  10.066916  2460056
# 1358  10.284278  2460058
#
# [13553 rows x 29 columns]

# %% [markdown]
# ### Debug

# %%
df.agg({"nalerthist": "max"}).collect()[0]
# Out:
# Row(max(nalerthist)=198)

# %%
large_lc_id = df.filter(df.nalerthist > 150).select("objectId").distinct().toPandas()

# %%
large_lc = df.filter(df.objectId.isin(list(large_lc_id.objectId.values))).toPandas()

# %%
large_lc["fink_class"].unique()
# Out:
# array(['Unknown', 'LPV*', 'CV*_Candidate', 'EB*_Candidate', 'Mira',
#        'RRLyr', 'BLLac', 'QSO', 'EB*', 'Star', 'Candidate_LP*',
#        'Candidate_EB*', 'V*', 'Seyfert_1', 'Candidate_CV*', 'Radio',
#        'LP*_Candidate', 'SN', 'MolCld', 'WD*', 'low-mass*',
#        'SN candidate', 'Microlensing candidate'], dtype=object)

# %%
large_lc[large_lc["fink_class"] == "Seyfert_1"]
# Out:
#            objectId               candid fink_class          ra        dec  \
# 109    ZTF18aauselm  1786117031415010010  Seyfert_1  291.831507  65.565079
# 115    ZTF18aauselm  1748220771415010006  Seyfert_1  291.831474  65.565078
# 125    ZTF18aauselm  1748191556115010002  Seyfert_1  291.831428  65.565070
# 140    ZTF18aauselm  1413217741415010015  Seyfert_1  291.831517  65.565075
# 165    ZTF18aauselm  1775220851415010009  Seyfert_1  291.831461  65.565086
# ...             ...                  ...        ...         ...        ...
# 27775  ZTF18aauselm  1581451856115010000  Seyfert_1  291.831414  65.565087
# 27777  ZTF18aauselm  1287278866115010003  Seyfert_1  291.831393  65.565110
# 27778  ZTF18aauselm  1161469251415010023  Seyfert_1  291.831436  65.565079
# 27854  ZTF18aauselm  1616455791415010013  Seyfert_1  291.831380  65.565097
# 27872  ZTF18aauselm  1318351751415010012  Seyfert_1  291.831417  65.565086
#
#           magpsf  sigmapsf  diffmaglim  fid            jd  ...  \
# 109    16.328951  0.029944   19.530504    1  2.459541e+06  ...
# 115    16.325113  0.031218   19.617287    1  2.459503e+06  ...
# 125    15.918632  0.044043   19.767838    2  2.459503e+06  ...
# 140    16.338615  0.037648   19.755213    2  2.459168e+06  ...
# 165    16.320475  0.037441   19.823141    1  2.459530e+06  ...
# ...          ...       ...         ...  ...           ...  ...
# 27775  16.118525  0.034950   19.732033    1  2.459336e+06  ...
# 27777  15.941357  0.051690   20.455849    2  2.459042e+06  ...
# 27778  16.421864  0.028015   18.969128    1  2.458916e+06  ...
# 27854  16.341091  0.050912   20.526621    2  2.459371e+06  ...
# 27872  16.359987  0.034888   20.147535    1  2.459073e+06  ...
#
#        jd_first_real_det  jdstarthist_dt  mag_rate  sigma_rate  lower_rate  \
# 109         2.459511e+06     1267.652049  0.007016    0.001561    0.004260
# 115         2.459474e+06     1230.750590  0.014764    0.001564    0.012121
# 125         2.459474e+06     1230.750590  0.010226    0.002134    0.007415
# 140         2.459138e+06      894.733368  0.025923    0.001848    0.022878
# 165         2.459503e+06     1259.648044  0.014764    0.001659    0.012279
# ...                  ...             ...       ...         ...         ...
# 27775       2.459307e+06     1063.943993 -0.007891    0.001784   -0.010990
# 27777       2.459012e+06      768.822627  0.010716    0.002035    0.007758
# 27778       2.458889e+06      646.026794  0.019804    0.001889    0.016629
# 27854       2.459342e+06     1098.876134  0.025360    0.001874    0.022386
# 27872       2.459043e+06      799.894688 -0.000104    0.001711   -0.002769
#
#        upper_rate  delta_time  from_upper  year  month
# 109      0.009508   29.899155       False  2021     11
# 115      0.017224   28.849456       False  2021     10
# 125      0.013583   28.952141       False  2021     10
# 140      0.029050   27.979213       False  2020     11
# 165      0.017680   27.083993       False  2021     11
# ...           ...         ...         ...   ...    ...
# 27775   -0.004891   29.019039       False  2021      5
# 27777    0.014061   29.947349       False  2020      7
# 27778    0.022536   22.912002       False  2020      3
# 27854    0.028624   29.002859       False  2021      6
# 27872    0.002807   29.122720       False  2020      8
#
# [1188 rows x 25 columns]

# %%
plot_magnitude_and_rate(large_lc[large_lc["objectId"] == "ZTF17aaafkxc"])

# %%
data = large_lc[large_lc["objectId"] == "ZTF17aaafkxc"].sort_values("jd")

# %%
data[["mag_rate", "magpsf", "jd"]]
# Out:
#        mag_rate     magpsf            jd
# 2234   0.034448  13.346504  2.458790e+06
# 14348  0.032246  13.343421  2.458790e+06
# 14346  0.030673  13.300246  2.458790e+06
# 13487  0.048316  15.725523  2.458790e+06
# 14259  0.048595  15.728276  2.458790e+06
# ...         ...        ...           ...
# 1606   0.038415  19.100367  2.459985e+06
# 1591   0.024754  18.675932  2.459985e+06
# 1862  -0.155404  16.675854  2.459992e+06
# 9270   0.056841  16.906393  2.459992e+06
# 2282  -0.022005  18.409389  2.459994e+06
#
# [1373 rows x 3 columns]

# %%
diff_rate = np.diff(data["magpsf"]) / np.diff(data["jd"])
# Out:
# /opt/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(10, 10))
diff_rate_sub = diff_rate[(diff_rate > -10) & (diff_rate < 10)]
plt.scatter(np.arange(len(diff_rate_sub)), diff_rate_sub)
plt.show()

# %%
plt.figure(figsize=(10, 10))
data_rate = data[(data["mag_rate"] > -10) & (data["mag_rate"] < 10)]
data_rate_fid_1 = data_rate[data_rate["fid"] == 1]["mag_rate"]
data_rate_fid_2 = data_rate[data_rate["fid"] == 2]["mag_rate"]
plt.scatter(np.arange(len(data_rate_fid_1)), data_rate_fid_1)
plt.scatter(np.arange(len(data_rate_fid_2)), data_rate_fid_2)
plt.show()

# %%
plot_magnitude_and_rate(large_lc[large_lc["objectId"] == "ZTF18acbwaxk"])

# %%
plot_magnitude_and_rate(large_lc[large_lc["objectId"] == "ZTF18aauselm"])
